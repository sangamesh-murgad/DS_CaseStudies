# %% [markdown]
# # FraudCheck with Risk Category

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.model_selection import KFold, cross_val_score
from sklearn.ensemble import BaggingClassifier,RandomForestClassifier, AdaBoostClassifier, StackingClassifier

# %% [markdown]
# ## problem statement
#
# Use RandomForsest to prepare a model on fraud data treating those who have taxable_income <= 30000 as "Risky" and others are "Good"
#
# ## Data Description :
#
#     Undergrad           :   person is under graduated or not
#     Marital.Status      :   marital status of a person
#     Taxable.Income      :   Taxable income is the amount of how much tax an individual owes to the government
#     Work Experience     :   Work experience of an individual person
#     Urban               :   Whether that person belongs to urban area or not

# %% [markdown]
# ## EDA Phase

# %%
rawData = pd.read_csv('Fraud_Check.csv')
rawData
# Out:
#     Undergrad Marital.Status  Taxable.Income  City.Population  \
# 0          NO         Single           68833            50047
# 1         YES       Divorced           33700           134075
# 2          NO        Married           36925           160205
# 3         YES         Single           50190           193264
# 4          NO        Married           81002            27533
# ..        ...            ...             ...              ...
# 595       YES       Divorced           76340            39492
# 596       YES       Divorced           69967            55369
# 597        NO       Divorced           47334           154058
# 598       YES        Married           98592           180083
# 599        NO       Divorced           96519           158137
#
#      Work.Experience Urban
# 0                 10   YES
# 1                 18   YES
# 2                 30   YES
# 3                 15   YES
# 4                 28    NO
# ..               ...   ...
# 595                7   YES
# 596                2   YES
# 597                0   YES
# 598               17    NO
# 599               16    NO
#
# [600 rows x 6 columns]

# %%
rawData.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 600 entries, 0 to 599
# Data columns (total 6 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Undergrad        600 non-null    object
#  1   Marital.Status   600 non-null    object
#  2   Taxable.Income   600 non-null    int64
#  3   City.Population  600 non-null    int64
#  4   Work.Experience  600 non-null    int64
#  5   Urban            600 non-null    object
# dtypes: int64(3), object(3)
# memory usage: 28.2+ KB

# %%
X = rawData.drop('Taxable.Income',axis=1).copy(deep=True)
X
# Out:
#     Undergrad Marital.Status  City.Population  Work.Experience Urban
# 0          NO         Single            50047               10   YES
# 1         YES       Divorced           134075               18   YES
# 2          NO        Married           160205               30   YES
# 3         YES         Single           193264               15   YES
# 4          NO        Married            27533               28    NO
# ..        ...            ...              ...              ...   ...
# 595       YES       Divorced            39492                7   YES
# 596       YES       Divorced            55369                2   YES
# 597        NO       Divorced           154058                0   YES
# 598       YES        Married           180083               17    NO
# 599        NO       Divorced           158137               16    NO
#
# [600 rows x 5 columns]

# %%
Y = rawData['Taxable.Income']
Y
# Out:
# 0      68833
# 1      33700
# 2      36925
# 3      50190
# 4      81002
#        ...
# 595    76340
# 596    69967
# 597    47334
# 598    98592
# 599    96519
# Name: Taxable.Income, Length: 600, dtype: int64

# %%
Y = Y.apply(lambda Y:'Risky' if Y <= 30000 else 'Good')
Y
# Out:
# 0      Good
# 1      Good
# 2      Good
# 3      Good
# 4      Good
#        ...
# 595    Good
# 596    Good
# 597    Good
# 598    Good
# 599    Good
# Name: Taxable.Income, Length: 600, dtype: object

# %%
Y.value_counts()
# Out:
# Good     476
# Risky    124
# Name: Taxable.Income, dtype: int64

# %%
for i in range(len(X.columns)):
#     print(X[X.columns[i]])
    if X[X.columns[i]].dtypes == 'object':
        print(X[X.columns[i]].value_counts())
    else:
        pass
# Out:
# YES    312
# NO     288
# Name: Undergrad, dtype: int64
# Single      217
# Married     194
# Divorced    189
# Name: Marital.Status, dtype: int64
# YES    302
# NO     298
# Name: Urban, dtype: int64

# %% [markdown]
# the above code can be directly written as
# for i in X.columns:
#     if X[i].dtypes == object:
#         print(X[i].value_counts())

# %%
X = pd.get_dummies(X)
X.head()
# Out:
#    City.Population  Work.Experience  Undergrad_NO  Undergrad_YES  \
# 0            50047               10             1              0
# 1           134075               18             0              1
# 2           160205               30             1              0
# 3           193264               15             0              1
# 4            27533               28             1              0
#
#    Marital.Status_Divorced  Marital.Status_Married  Marital.Status_Single  \
# 0                        0                       0                      1
# 1                        1                       0                      0
# 2                        0                       1                      0
# 3                        0                       0                      1
# 4                        0                       1                      0
#
#    Urban_NO  Urban_YES
# 0         0          1
# 1         0          1
# 2         0          1
# 3         0          1
# 4         1          0

# %%
X2 = X.drop(['Undergrad_NO', 'Marital.Status_Single', 'Urban_NO'],axis=1)
X2
# Out:
#      City.Population  Work.Experience  Undergrad_YES  Marital.Status_Divorced  \
# 0              50047               10              0                        0
# 1             134075               18              1                        1
# 2             160205               30              0                        0
# 3             193264               15              1                        0
# 4              27533               28              0                        0
# ..               ...              ...            ...                      ...
# 595            39492                7              1                        1
# 596            55369                2              1                        1
# 597           154058                0              0                        1
# 598           180083               17              1                        0
# 599           158137               16              0                        1
#
#      Marital.Status_Married  Urban_YES
# 0                         0          1
# 1                         0          1
# 2                         1          1
# 3                         0          1
# 4                         1          0
# ..                      ...        ...
# 595                       0          1
# 596                       0          1
# 597                       0          1
# 598                       1          0
# 599                       0          0
#
# [600 rows x 6 columns]

# %% [markdown]
# ## Feature Engineering
#
# ### PPSCORE

# %%
import ppscore as pps

# %%
pps.matrix(rawData,sorted=True)
# Out:
#                   x                y   ppscore            case  \
# 0         Undergrad        Undergrad  1.000000  predict_itself
# 1    Marital.Status   Marital.Status  1.000000  predict_itself
# 2    Taxable.Income   Taxable.Income  1.000000  predict_itself
# 3   City.Population  City.Population  1.000000  predict_itself
# 4   Work.Experience  Work.Experience  1.000000  predict_itself
# 5             Urban            Urban  1.000000  predict_itself
# 6    Taxable.Income            Urban  0.069812  classification
# 7   Work.Experience            Urban  0.054289  classification
# 8    Taxable.Income   Marital.Status  0.034290  classification
# 9    Marital.Status   Taxable.Income  0.007396      regression
# 10        Undergrad  City.Population  0.006556      regression
# 11   Marital.Status            Urban  0.001463  classification
# 12            Urban  City.Population  0.000576      regression
# 13            Urban   Taxable.Income  0.000138      regression
# 14        Undergrad   Marital.Status  0.000000  classification
# 15        Undergrad   Taxable.Income  0.000000      regression
# 16        Undergrad  Work.Experience  0.000000      regression
# 17        Undergrad            Urban  0.000000  classification
# 18   Marital.Status        Undergrad  0.000000  classification
# 19   Marital.Status  City.Population  0.000000      regression
# 20   Marital.Status  Work.Experience  0.000000      regression
# 21   Taxable.Income        Undergrad  0.000000  classification
# 22   Taxable.Income  City.Population  0.000000      regression
# 23   Taxable.Income  Work.Experience  0.000000      regression
# 24  City.Population        Undergrad  0.000000  classification
# 25  City.Population   Marital.Status  0.000000  classification
# 26  City.Population   Taxable.Income  0.000000      regression
# 27  City.Population  Work.Experience  0.000000      regression
# 28  City.Population            Urban  0.000000  classification
# 29  Work.Experience        Undergrad  0.000000  classification
# 30  Work.Experience   Marital.Status  0.000000  classification
# 31  Work.Experience   Taxable.Income  0.000000      regression
# 32  Work.Experience  City.Population  0.000000      regression
# 33            Urban        Undergrad  0.000000  classification
# 34            Urban   Marital.Status  0.000000  classification
# 35            Urban  Work.Experience  0.000000      regression
#
#     is_valid_score               metric  baseline_score   model_score  \
# 0             True                 None        0.000000      1.000000
# 1             True                 None        0.000000      1.000000
# 2             True                 None        0.000000      1.000000
# 3             True                 None        0.000000      1.000000
# 4             True                 None        0.000000      1.000000
# 5             True                 None        0.000000      1.000000
# 6             True          weighted F1        0.493333      0.528705
# 7             True          weighted F1        0.493333      0.520840
# 8             True          weighted F1        0.333333      0.356193
# 9             True  mean absolute error    22771.961667  22603.545807
# 10            True  mean absolute error    42730.781667  42450.626013
# 11            True          weighted F1        0.493333      0.494075
# 12            True  mean absolute error    42730.781667  42706.182288
# 13            True  mean absolute error    22771.961667  22768.829023
# 14            True          weighted F1        0.333333      0.211271
# 15            True  mean absolute error    22771.961667  22779.973615
# 16            True  mean absolute error        7.598333      7.710043
# 17            True          weighted F1        0.493333      0.437896
# 18            True          weighted F1        0.513333      0.464649
# 19            True  mean absolute error    42730.781667  42890.394252
# 20            True  mean absolute error        7.598333      7.701853
# 21            True          weighted F1        0.513333      0.481103
# 22            True  mean absolute error    42730.781667  59151.176667
# 23            True  mean absolute error        7.598333     10.091667
# 24            True          weighted F1        0.513333      0.474480
# 25            True          weighted F1        0.333333      0.331360
# 26            True  mean absolute error    22771.961667  29853.625000
# 27            True  mean absolute error        7.598333     10.061667
# 28            True          weighted F1        0.493333      0.487383
# 29            True          weighted F1        0.513333      0.501230
# 30            True          weighted F1        0.333333      0.319831
# 31            True  mean absolute error    22771.961667  24035.718747
# 32            True  mean absolute error    42730.781667  43649.215999
# 33            True          weighted F1        0.513333      0.394612
# 34            True          weighted F1        0.333333      0.233828
# 35            True  mean absolute error        7.598333      7.674446
#
#                        model
# 0                       None
# 1                       None
# 2                       None
# 3                       None
# 4                       None
# 5                       None
# 6   DecisionTreeClassifier()
# 7   DecisionTreeClassifier()
# 8   DecisionTreeClassifier()
# 9    DecisionTreeRegressor()
# 10   DecisionTreeRegressor()
# 11  DecisionTreeClassifier()
# 12   DecisionTreeRegressor()
# 13   DecisionTreeRegressor()
# 14  DecisionTreeClassifier()
# 15   DecisionTreeRegressor()
# 16   DecisionTreeRegressor()
# 17  DecisionTreeClassifier()
# 18  DecisionTreeClassifier()
# 19   DecisionTreeRegressor()
# 20   DecisionTreeRegressor()
# 21  DecisionTreeClassifier()
# 22   DecisionTreeRegressor()
# 23   DecisionTreeRegressor()
# 24  DecisionTreeClassifier()
# 25  DecisionTreeClassifier()
# 26   DecisionTreeRegressor()
# 27   DecisionTreeRegressor()
# 28  DecisionTreeClassifier()
# 29  DecisionTreeClassifier()
# 30  DecisionTreeClassifier()
# 31   DecisionTreeRegressor()
# 32   DecisionTreeRegressor()
# 33  DecisionTreeClassifier()
# 34  DecisionTreeClassifier()
# 35   DecisionTreeRegressor()

# %%
pps.matrix(rawData,sorted=True)[pps.matrix(rawData,sorted=True).y == 'Taxable.Income']
# Out:
#                   x               y   ppscore            case  is_valid_score  \
# 2    Taxable.Income  Taxable.Income  1.000000  predict_itself            True
# 9    Marital.Status  Taxable.Income  0.007396      regression            True
# 13            Urban  Taxable.Income  0.000138      regression            True
# 15        Undergrad  Taxable.Income  0.000000      regression            True
# 26  City.Population  Taxable.Income  0.000000      regression            True
# 31  Work.Experience  Taxable.Income  0.000000      regression            True
#
#                  metric  baseline_score   model_score                    model
# 2                  None        0.000000      1.000000                     None
# 9   mean absolute error    22771.961667  22603.545807  DecisionTreeRegressor()
# 13  mean absolute error    22771.961667  22768.829023  DecisionTreeRegressor()
# 15  mean absolute error    22771.961667  22779.973615  DecisionTreeRegressor()
# 26  mean absolute error    22771.961667  29853.625000  DecisionTreeRegressor()
# 31  mean absolute error    22771.961667  24035.718747  DecisionTreeRegressor()

# %% [markdown]
# **Based on PPS scores. There are no good features that independently predict the Taxable income in the given dataset. let us check how do they perform using RFE technique.**

# %% [markdown]
# ## Feature Engineering
# ### RecursiveFeatureElemination(RFE)

# %%
from sklearn.feature_selection import RFE
from sklearn.tree import DecisionTreeClassifier

# %%
DTC = DecisionTreeClassifier()
rfe = RFE(DTC,n_features_to_select=1,verbose=1)
fit = rfe.fit(X2,Y)
fit.support_
# Out:
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# Fitting estimator with 2 features.
# array([ True, False, False, False, False, False])

# %%
fit.ranking_,X2.columns
# Out:
# (array([1, 2, 3, 6, 5, 4]),
#  Index(['City.Population', 'Work.Experience', 'Undergrad_YES',
#         'Marital.Status_Divorced', 'Marital.Status_Married', 'Urban_YES'],
#        dtype='object'))

# %%
confusion_matrix(Y,fit.predict(X2))
# Out:
# array([[476,   0],
#        [  1, 123]], dtype=int64)

# %%
DTC = DecisionTreeClassifier()
rfe = RFE(DTC,n_features_to_select=2,verbose=3)
fit = rfe.fit(X2,Y)
fit.ranking_
# Out:
# Fitting estimator with 6 features.
# Fitting estimator with 5 features.
# Fitting estimator with 4 features.
# Fitting estimator with 3 features.
# array([1, 1, 4, 5, 2, 3])

# %%
confusion_matrix(Y,fit.predict(X2)) # this accuracy is not reliable as all the decision trees are built to pure region.
# Out:
# array([[476,   0],
#        [  0, 124]], dtype=int64)

# %% [markdown]
# **The Recursive Elemination process suggests that 'City.Population' and 'Work.Experience' together are good to predict y variable. let us prceed to build our Random forest with cross validation.**

# %% [markdown]
# ### TrainTestSplit for model Training and Validation

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test = train_test_split(X2,Y,test_size=.5,random_state=42)
print(X_train.shape,X_test.shape)
print(Y_train.shape,Y_test.shape)
Y_train.value_counts(),Y_test.value_counts()
# Out:
# (300, 6) (300, 6)
# (300,) (300,)
# (Good     242
#  Risky     58
#  Name: Taxable.Income, dtype: int64,
#  Good     234
#  Risky     66
#  Name: Taxable.Income, dtype: int64)

# %% [markdown]
# # Model Building / Validation
# ## Random Forest Classifier

# %%
kfold = KFold(n_splits=10)
RFT = RandomForestClassifier(random_state=0)
result = cross_val_score(RFT,X_train,Y_train,cv=kfold)

# %%
result.mean(),result.std()
# Out:
# (0.76, 0.085374989832438)

# %%
RFT.fit(X_train,Y_train)
RFT.score(X_train,Y_train)
# Out:
# 1.0

# %%
confusion_matrix(Y_train,RFT.predict(X_train))
# Out:
# array([[242,   0],
#        [  0,  58]], dtype=int64)

# %%
print(classification_report(Y_train,RFT.predict(X_train)))
# Out:
#               precision    recall  f1-score   support
#
#         Good       1.00      1.00      1.00       242
#        Risky       1.00      1.00      1.00        58
#
#     accuracy                           1.00       300
#    macro avg       1.00      1.00      1.00       300
# weighted avg       1.00      1.00      1.00       300

# %%
RFT.predict(X_test)
# Out:
# array(['Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Risky', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Risky',
#        'Good', 'Risky', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good', 'Good',
#        'Good', 'Good', 'Good', 'Good'], dtype=object)

# %%
RFT.score(X_test,Y_test)
# Out:
# 0.7466666666666667

# %%
confusion_matrix(Y_test,RFT.predict(X_test))
# Out:
# array([[222,  12],
#        [ 64,   2]], dtype=int64)

# %%
print(classification_report(Y_test,RFT.predict(X_test)))
# Out:
#               precision    recall  f1-score   support
#
#         Good       0.78      0.95      0.85       234
#        Risky       0.14      0.03      0.05        66
#
#     accuracy                           0.75       300
#    macro avg       0.46      0.49      0.45       300
# weighted avg       0.64      0.75      0.68       300

# %% [markdown]
# **There seems to be a problem of overfitting**
#
# **As expected the model does not fare well in identifying the risky data. eventhough the overall accuracy is ok at 75%, the precision for 'risky' category is as low as 14%, further specificity is even low @ 3%. As stated in the PPS score that there are no good features to predict the Y variable, our model suffers in performance.**
#
# **May be we need to look at the source of the data and rework on the selecting and collecting/sourcing right features for prediction.**
